# %%
class BPP:
    # This class groups the bin packing problem information.
    def __init__(self, n, wbin, ub, lb):
        self.n = int(n)
        self.wbin = wbin
        self.ub = ub
        self.lb = int(lb)

    def getwbin(self):
        return self.wbin

    def getub(self):
        return self.ub

    def getlb(self):
        return self.lb

# %%
class MOproblem:
    # This class maintains the overall multi-objective problem.
    def __init__(self, nso, items):
        self.nso = nso      # number of single-objective subproblems
        self.nobj = 3       # number of objective functions
        self.items = items
        self.lambdas = []
        self.weights = np.zeros((len(items), 1))
        self.heights = np.zeros((len(items), 1))
        self.makematrix()   # make N_so subproblems

    def makematrix(self):
        # This function selects N weight vectors and forms the
        # N_so subproblems. It also initializes the weight and
        # height matrices.
        random.seed(68)
        for k in range(self.nso):
            high = 1
            lambdak = np.zeros(self.nobj)
            for w in range(self.nobj - 1):
                lambdak[w] = random.uniform(0, high)
                high -= lambdak[w]
            lambdak[self.nobj-1] = 1 - np.sum(lambdak)
            self.lambdas.append(lambdak)
        for j in range(len(self.items)):
            self.weights[j, 0] = self.items[j].getweight()
            self.heights[j, 0] = self.items[j].getheight()

    def subfit(self, k, chrom, bpp, method):
        # This function calculates the fitness value for subprob. k
        # Options: 'ed', 'll', 'dp', 'combo'
        if method == 'ed':
            x, y = bp.ed(0, chrom, bpp, self.items)
        else:
            x, y = bp.ll(chrom, bpp.getwbin(), bpp.getub(), bpp.getlb(), self.items)
        subfit = np.dot(self.lambdas[k], self.calcfits(x, y))
        return x, y, subfit

    def calcfits(self, x, y):
        # This module calculates the fitness values for a solution.
        # To run this module, enable the following line:
        # import numpy as np
        fitvals = np.zeros(self.nobj)
        # Objective Function 1 min. # of bins
        fitvals[0] = np.sum(y)
        # Objective Function 2 min. H of bins
        his = np.dot(x, self.heights)
        fitvals[1] = np.amax(his)
        # Objective Function 3 min. Average Bin weight
        wis = np.dot(x, self.weights)
        fitvals[2] = np.amax(wis)
        return fitvals

# %%
def sorank(setp):
    # Fast sorting to obtain single-objective ranks
    numsol = len(setp)
    setp.sort(key=attrgetter('fits'))
    prank = 1
    for m in range(numsol-1):
        setp[m].updaterank(prank)
        if setp[m].getfits() != setp[m+1].getfits():
            prank += 1
    setp[-1].updaterank(prank)
    return setp

# %%
def see(ndset, folder):
    # see prints out a file to show how x and y for a gene
    # To run this module, enable the following line:
    # import numpy as np
    dir = folder + 'variables/'
    os.mkdir(dir)
    for m in ndset:
        x, y = m.getx(), m.gety()
        solid = str(m.getindex())
        np.savetxt(dir + solid + '_x.txt', x, fmt='%i', header='Item Location Matrix x:')
        np.savetxt(dir + solid + '_y.txt', y, fmt='%i', header='Bins Used Matrix y:')

# %%
class MOMADgen:
    def __init__(self, n, bpp, moop, items, end):
        self.n = int(n)
        self.t = 0
        self.pl = []      # current solutions for subproblems
        self.pp = []      # solutions to undergo PLS
        self.pe = []      # external pop. of nondominated solutions
        self.end = int(end)
        self.bpp = bpp
        self.moop = moop
        self.idnum = 0
        self.items = items
        self.funkeval = 0
        self.chrom = []
        self.makechroms()

    def rungen(self):
        self.t += 1
        print('t = ', self.t)
        print('Step 2: Pareto Local Search')
        maxmum = 10
        self.pls(maxmum)
        self.pp = []
        print('Step 3: Perturb, Local Search, and Update Populations')
        for k in range(self.moop.nso):
            print('     Perturbing P_L member', k)
            xksquiggly = self.perturb(self.pl[k])
            yk = self.localsh(k, xksquiggly)
            self.update1(yk)
            self.pe = self.update2(yk, self.pe)
            if yk in self.pe:
                self.pp = self.update2(yk, self.pp)
        print(self.funkeval, 'function evaluations have been performed.\n')

    def updatefe(self):
        # This function keeps track of the number of function evaluations.
        self.funkeval += 1

    def endgen(self):
        # Step 1 of MOMAD
        return self.funkeval > self.end

    def makechroms(self):
        for j in range(self.n):
            self.chrom.append(self.items[j].getindex())

    def initialize(self):
        # This function is Step 0 in MOMAD. It initializes P_L, P_P, and P_E.
        print('Initialization starting...')
        # Step 0.1: Initialization of P_L
        for k in range(self.moop.nso):
            print('     Searching for P_L member', k)
            xkso = self.soga(k, 20, 5)
            fit = self.moop.calcfits(xkso.getx(), xkso.gety())
            xk = sol.MultiSol(self.idnum, xkso.getgenes(), xkso.getx(), xkso.gety(), 0, fit, 0, 0.0)
            self.updateid()
            self.pl.append(xk)
        print('Step 0.1: Initialize P_L: complete')
        # Step 0.2: Initialization of  P_p and P_e
        self.pl, fronts = mop.fnds(self.pl)
        self.pp = fronts[0]
        self.pe = self.pp
        print('Step 0.2: Initalize P_P and P_E: complete')
        print(self.funkeval, 'function evaluations were performed in Step 0.\n')

    def pls(self, maxmum):
        # This function performs the Pareto Local Search from Ke(2014).
        # Step 2 in MOMAD.
        # input: pp, pl, pe, maxmum
        # output: pl, pe
        m = 0
        while self.pp != [] and m < maxmum:
            palpha = []
            for x in range(len(self.pp)):
                print('     Searching near solution', self.pp[x].getindex())
                nofx = self.neighborhood(self.pp[x], 50)
                for y in range(len(nofx)):
                    self.update1(nofx[y])
                    if mop.dom(nofx[y].getfits(), self.pp[x].getfits()):
                        self.pe = self.update2(nofx[y], self.pe)
                        if nofx[y] in self.pe:
                            palpha = self.update2(nofx[y], palpha)
            self.pp = list(palpha)
            m += 1

    def perturb(self, xk):
        # This function performs the pertubation in Step 3.1 of MOMAD.
        alpha = random.random()
        if alpha == 0:
            alpha = random.random()
        blocklen = int(alpha * self.n)
        splitj = self.n - blocklen
        cut1 = xk.getgenes()[:splitj]
        cut2 = xk.getgenes()[splitj:]
        cut3 = random.sample(cut2, len(cut2))
        newgene = cut1 + cut3
        x, y = bp.ed(self.idnum, newgene, self.bpp, self.items)
        fit = self.moop.calcfits(x, y)
        xksquiggly = sol.MultiSol(self.idnum, newgene, x, y, self.t, fit, 0, 0.0)
        self.updateid()
        self.updatefe()
        return xksquiggly

    def localsh(self, k, xk):
        # This function performs the local search in Step 3.2 of MOMAD.
        # Uses reduced variable neighborhood search
        # kmax = 1
        m = 0
        while m < 25:
            neighbor = self.neighborhood(xk, 1)
            yk = neighbor[0]
            x1, y1, sofit1 = self.moop.subfit(k, yk.getgenes(), self.bpp, 'ed')
            x2, y2, sofit2 = self.moop.subfit(k, xk.getgenes(), self.bpp, 'ed')
            if sofit1 < sofit2:
                xk = yk
            m += 1
        return xk

    def update1(self, y):
        # This function performs the Update1 algorithm from Ke(2014).
        # input: pl, y
        # output: pl
        replacement = False
        palpha = list(self.pl)
        while palpha != [] and replacement is False:
            x = random.choice(palpha)
            k = self.pl.index(x)
            palpha.remove(x)
            x1, y1, sofit1 = self.moop.subfit(k, y.getgenes(), self.bpp, 'ed')
            x2, y2, sofit2 = self.moop.subfit(k, x.getgenes(), self.bpp, 'ed')
            if sofit1 < sofit2:
                self.pl[k] = y
                replacement = True
            self.updatefe()

    def update2(self, y, setp):
        # This function performs the Update2 algorithm from Ke(2014).
        # input: setp, y
        # output: setp
        palpha = list(setp)
        palpha.append(y)
        palpha, fronts = mop.fnds(palpha)
        setp = fronts[0]  # Nondominated front for palpha is now setp
        # The last step effectively removes all solutions in setp that
        # are dominated by y and adds y to setp if nondominated
        return setp

    def soga(self, k, mems, numgen):
        # Initialize single-objective solutions using genetic algorithm
        q = []
        newgenes = []
        for t in range(numgen):
            print('         Subgeneration', t)
            p, newgenes = self.makesop(t, mems, q, newgenes)
            if t != 0:
                q = ga.binsel(p, mems, 'elitism')
                newgenes = ga.xover(q, mems)
                newgenes = ga.mutat(self.n, newgenes, mems)
            q = self.makesoq(t, mems, k, p, q, newgenes)
            self.updatefe()
        q = sorank(q)
        return q[0]

    def makesop(self, t, mems, q, newgenes):
        # Part of soga(), makes P
        if t == 0:
            p = []
            for m in range(mems):
                a = random.sample(self.chrom, self.n)
                newgenes.append(a)
        else:
            p = q
        return p, newgenes

    def makesoq(self, t, mems, k, p, q, newgenes):
        # Part of soga(), makes Q
        if t == 0:
            new = range(mems)
        else:
            new, q = sol.oldnew(p, q, newgenes)
        for m in new:
            x, y, fit = self.moop.subfit(k, newgenes[m], self.bpp, 'll')
            q.append(sol.Sol(m, newgenes[m], x, y, 0, fit, 0))
        q = sorank(q)
        return q

    def neighborhood(self, m, hoodsize):
        # This function takes solution m and finds all of its neighbors.
        # input: m
        # output: the set of m's neighbors
        # Limiting neighborhood to 100 neighbors to reduce computationload
        neighbors = []
        while len(neighbors) < hoodsize:
            newgene = m.getgenes()
            a = random.randrange(0, len(newgene))
            b = random.randrange(0, len(newgene))
            newgene[a], newgene[b] = newgene[b], newgene[a]
            x, y = bp.ed(self.idnum, newgene, self.bpp, self.items)
            fit = self.moop.calcfits(x, y)
            a = sol.MultiSol(self.idnum, newgene, x, y, self.t, fit, 0, 0.0)
            neighbors.append(a)
            self.updateid()
        return neighbors

    def updateid(self):
        self.idnum += 1

    def gett(self):
        return self.t

    def getpl(self):
        return self.pl

    def getpe(self):
        return self.pe

# %%
n = 500
folder = '/Users/gelliebeenz/Documents/Python/ObjectiveMethod/MOMAD/Static/SBSBPP500/Experiment01/'
file = 'SBSBPP500_run1.txt'

# %%
from __future__ import print_function
import binpacking as bp
import ga
import mop
import numpy as np
import os
import random
import solutions as sol
from operator import attrgetter
import datetime
import outformat as outf
from glob import glob
import items

# %%
existing_files = glob(folder + '*.out')
filename = folder + 'run%d.out' % (len(existing_files) + 1)
data = folder + file

# Initialize Algorithm
end = 25000  # function evaluations
method = 'MOMAD'
outf.startout(filename, n, end, data, method)
startt = datetime.datetime.now()
print('                         ', startt)
print('*******************************************************************************')
print('     Method: MOMAD \n')
print('     data: ', file)
print('*******************************************************************************')
if n <= 600:
    nso = n
else:
    nso = 600  # number of single-objective functions
binc, binh, minbin, items = items.makeitems(data)
bpp = BPP(n, binc, binh, minbin)
moop = MOproblem(nso, items)
gen = MOMADgen(n, bpp, moop, items, end)
gen.initialize()
# Out:
#                           2016-07-18 13:45:05.648421
# *******************************************************************************
#      Method: MOMAD
#
#      data:  SBSBPP500_run1.txt
# *******************************************************************************
# Initialization starting...
#      Searching for P_L member 0
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 1
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 2
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 3
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 4
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 5
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 6
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 7
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 8
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 9
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 10
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 11
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 12
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 13
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 14
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 15
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 16
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 17
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 18
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 19
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 20
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 21
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 22
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 23
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 24
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 25
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 26
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 27
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 28
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 29
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 30
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 31
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 32
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 33
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 34
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 35
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 36
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 37
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 38
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 39
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 40
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 41
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 42
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 43
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 44
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 45
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 46
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 47
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 48
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 49
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 50
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 51
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 52
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 53
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 54
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 55
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 56
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 57
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 58
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 59
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 60
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 61
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 62
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 63
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 64
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 65
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 66
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 67
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 68
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 69
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 70
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 71
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 72
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 73
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 74
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 75
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 76
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 77
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 78
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 79
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 80
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 81
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 82
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 83
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 84
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 85
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 86
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 87
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 88
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 89
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 90
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 91
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 92
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 93
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 94
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 95
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 96
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 97
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 98
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 99
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 100
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 101
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 102
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 103
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 104
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 105
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 106
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 107
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 108
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 109
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 110
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 111
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 112
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 113
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 114
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 115
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 116
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 117
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 118
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 119
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 120
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 121
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 122
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 123
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 124
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 125
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 126
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 127
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 128
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 129
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 130
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 131
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 132
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 133
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 134
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 135
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 136
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 137
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 138
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 139
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 140
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 141
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 142
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 143
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 144
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 145
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 146
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 147
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 148
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 149
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 150
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 151
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 152
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 153
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 154
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 155
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 156
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 157
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 158
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 159
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 160
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 161
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 162
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 163
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 164
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 165
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 166
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 167
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 168
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 169
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 170
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 171
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 172
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 173
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 174
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 175
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 176
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 177
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 178
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 179
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 180
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 181
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 182
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 183
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 184
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 185
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 186
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 187
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 188
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 189
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 190
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 191
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 192
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 193
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 194
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 195
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 196
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 197
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 198
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 199
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 200
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 201
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 202
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 203
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 204
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 205
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 206
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 207
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 208
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 209
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 210
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 211
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 212
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 213
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 214
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 215
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 216
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 217
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 218
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 219
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 220
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 221
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 222
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 223
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 224
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 225
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 226
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 227
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 228
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 229
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 230
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 231
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 232
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 233
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 234
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 235
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 236
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 237
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 238
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 239
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 240
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 241
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 242
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 243
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 244
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 245
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 246
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 247
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 248
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 249
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 250
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 251
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 252
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 253
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 254
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 255
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 256
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 257
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 258
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 259
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 260
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 261
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 262
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 263
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 264
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 265
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 266
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 267
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 268
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 269
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 270
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 271
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 272
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 273
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 274
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 275
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 276
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 277
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 278
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 279
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 280
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 281
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 282
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 283
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 284
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 285
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 286
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 287
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 288
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 289
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 290
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 291
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 292
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 293
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 294
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 295
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 296
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 297
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 298
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 299
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 300
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
# ...
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 401
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 402
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 403
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 404
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 405
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 406
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 407
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 408
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 409
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 410
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 411
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 412
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 413
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 414
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 415
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 416
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 417
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 418
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 419
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 420
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 421
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 422
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 423
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 424
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 425
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 426
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 427
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 428
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 429
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 430
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 431
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 432
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 433
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 434
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 435
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 436
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 437
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 438
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 439
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 440
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 441
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 442
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 443
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 444
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 445
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 446
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 447
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 448
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 449
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 450
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 451
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 452
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 453
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 454
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 455
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 456
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 457
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 458
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 459
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 460
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 461
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 462
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 463
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 464
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 465
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 466
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 467
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 468
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 469
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 470
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 471
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 472
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 473
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 474
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 475
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 476
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 477
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 478
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 479
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 480
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 481
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 482
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 483
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 484
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 485
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 486
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 487
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 488
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 489
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 490
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 491
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 492
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 493
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 494
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 495
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 496
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 497
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 498
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
#      Searching for P_L member 499
#          Subgeneration 0
#          Subgeneration 1
#          Subgeneration 2
#          Subgeneration 3
#          Subgeneration 4
# Step 0.1: Initialize P_L: complete
# Step 0.2: Initalize P_P and P_E: complete
# 2500 function evaluations were performed in Step 0.

# %%
gen.t = 0
gen.t += 1
print('t = ', gen.t)
print('Step 2: Pareto Local Search')
maxmum = 10
gen.pls(maxmum)
gen.pp = []
print('Step 3: Perturb, Local Search, and Update Populations')
# Out:
# t =  1
# Step 2: Pareto Local Search
# Step 3: Perturb, Local Search, and Update Populations

# %%
k=0
print('     Perturbing P_L member', k)
xksquiggly = gen.perturb(gen.pl[k])
yk = gen.localsh(k, xksquiggly)
gen.update1(yk)
gen.pe = gen.update2(yk, gen.pe)
if yk in gen.pe:
    gen.pp = gen.update2(yk, gen.pp)
print(gen.funkeval, 'function evaluations have been performed.\n')
# Out:
#      Perturbing P_L member 0
# 3396 function evaluations have been performed.
